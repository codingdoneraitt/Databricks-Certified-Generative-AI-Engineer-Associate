# %% [markdown]
# # Lab 00-01: Workspace Orientation
#
# **Module:** 00 — Foundations
# **UI Sections:** Compute, Catalog
# **Estimated Time:** 30–40 minutes
#
# ---
#
# ## Learning Objectives
#
# - Explore the Databricks workspace UI and left-hand navigation
# - Create a cluster under **Compute**
# - Run a basic Python notebook
# - Read and write a Delta table
# - Run a SQL query using `%sql`
# - Understand the difference between classic clusters and serverless compute
#
# ---
#
# ## Exam Relevance
#
# This lab is foundational — no direct exam questions, but every subsequent lab depends on these skills.

# %% [markdown]
# ## Step 1: Explore the Workspace
#
# Navigate through each section of the left-hand menu. Note what lives where.

# %%
# Step 2: Verify your cluster is running and print the Spark version

# %%
# Step 3: Create a simple DataFrame and write it as a Delta table

# %%
# Step 4: Read the Delta table back

# %%
# Step 5: Query the table using SQL magic

# %% [markdown]
# ## Key Takeaways
#
# - Classic clusters: you manage sizing, auto-termination, and runtime version
# - Serverless compute: Databricks manages infrastructure — instant start, no cluster config
# - Delta tables are the default storage format on Databricks
