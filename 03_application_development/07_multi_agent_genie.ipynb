# %% [markdown]
# # Lab 03-07: Multi-Agent Systems and Genie
#
# **Module:** 03 — Application Development (30% of exam)
# **UI Sections:** Genie, Features, Experiments
# **Estimated Time:** 45–60 minutes
#
# ---
#
# ## Learning Objectives
#
# - Use **Genie** to run natural language queries over a structured Delta table
# - Navigate to **Features** and understand feature tables as an alternative retrieval source
# - Understand when to route a query to RAG agent vs Genie/data agent
# - Clearly compare evaluation (offline, pre-deployment) vs monitoring (online, post-deployment)
#
# ---
#
# ## Exam Objectives Covered
#
# - Multi-agent systems / Genie Spaces
# - Evaluation vs monitoring phases

# %%
# Step 1: Set up a Genie Space over a Delta table

# %%
# Step 2: Query Genie with natural language

# %%
# Step 3: Explore feature tables in the Features UI

# %%
# Step 4: Design routing logic — RAG agent vs Genie agent

# %%
# Step 5: Compare evaluation vs monitoring

# %% [markdown]
# ## Key Takeaways
#
# - Genie: natural language → SQL over structured Delta tables
# - Feature tables: structured data lookup by key (e.g., customer profile by account ID)
# - RAG agent: unstructured knowledge base queries
# - Genie agent: structured data queries
# - **Evaluation** = offline, pre-deployment, test datasets
# - **Monitoring** = online, post-deployment, real user traffic
