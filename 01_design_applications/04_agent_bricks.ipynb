# %% [markdown]
# # Lab 01-04: Agent Bricks
#
# **Module:** 01 — Design Applications (14% of exam)
# **UI Sections:** Discover, Marketplace
# **Estimated Time:** 30–40 minutes
#
# ---
#
# ## Learning Objectives
#
# - Use **Discover** and **Marketplace** to explore available model types and datasets
# - Learn the three Agent Brick types:
#   - **Knowledge Assistant** — pre-built RAG Q&A
#   - **Multiagent Supervisor** — orchestrates specialized sub-agents
#   - **Information Extraction** — structured output from unstructured documents
# - Practice matching a business scenario to the correct Agent Brick
#
# ---
#
# ## Exam Objectives Covered
#
# - Agent Bricks (Knowledge Assistant, Multiagent Supervisor, Information Extraction)

# %%
# Step 1: Explore the Discover page and list available model types

# %%
# Step 2: Browse Marketplace for pre-built models and datasets

# %%
# Step 3: Compare the three Agent Brick types

# %%
# Step 4: Practice — match business scenarios to Agent Bricks

# %% [markdown]
# ## Key Takeaways
#
# - **Knowledge Assistant**: best for Q&A over a knowledge base (RAG)
# - **Multiagent Supervisor**: best when different tasks need different specialized agents
# - **Information Extraction**: best for pulling structured data from unstructured documents
# - Discover and Marketplace are where you find and install models and datasets
